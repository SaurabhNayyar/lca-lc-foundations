# %%
from pprint import pprint

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("gpt-5-nano")

response = model.invoke("What is the capital of Moon?")

# %%
pprint(response)
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country or sovereign entity, so it has no capital city. If you’re asking about a fictional universe (book, movie, game), tell me which one and I can name the capital as it’s portrayed there.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1150, 'prompt_tokens': 13, 'total_tokens': 1163, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1088, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CuTNVCspqWJtgK0GKdQ2PjXmeYsq7', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8bb3-2414-7181-95d8-703768f14c19-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 1150, 'total_tokens': 1163, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1088}})
